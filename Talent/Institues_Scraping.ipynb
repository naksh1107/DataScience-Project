# %% [markdown]
# # Top Institutes in India

# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd
# from selenium import webdriver
# import time
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support.wait import WebDriverWait
# from selenium.webdriver.support import expected_conditions as EC

# %%
# def NIRF_scrape(url):
#     df= pd.read_html(url)[0]
#     del df['Institute ID']
#     df_sorted=df.sort_values(by ='City')
#     #value = input("Enter the State you want to sort it according: ")
#     #filtered_df = df[df['City'] == value]
    
    
#     return df


# def scrape_NIRF(writer,df):
#     df.to_excel(writer,sheet_name='NIRF Institute Rankings')
    
# df1=NIRF_scrape("https://www.nirfindia.org/Rankings/2023/EngineeringRanking.html")


# with pd.ExcelWriter('Institute_Rankings.xlsx') as writer:
#     scrape_NIRF(writer,df1)

# %%
pd.options.display.max_rows = 9999

# %% [markdown]
# ## NIRF INSTITUTE RANKINGS

# %%
df1.head(100)
# Out:
#                                                  Name                   City  \
# 0   Indian Institute of Technology MadrasMore Deta...                Chennai
# 1   Indian Institute of Technology DelhiMore Detai...              New Delhi
# 2   Indian Institute of Technology BombayMore Deta...                 Mumbai
# 3   Indian Institute of Technology KanpurMore Deta...                 Kanpur
# 4   Indian Institute of Technology RoorkeeMore Det...                Roorkee
# 5   Indian Institute of Technology KharagpurMore D...              Kharagpur
# 6   Indian Institute of Technology GuwahatiMore De...               Guwahati
# 7   Indian Institute of Technology HyderabadMore D...              Hyderabad
# 8   National Institute of Technology Tiruchirappal...        Tiruchirappalli
# 9                 Jadavpur UniversityMore Details | |                Kolkata
# 10    Vellore Institute of TechnologyMore Details | |                Vellore
# ...

# %% [markdown]
# ### NIRF BANGALORE RANKINGS

# %%
df1[df1['City']=="Bengaluru"]
# Out:
#                                                  Name       City      State  \
# 73  International Institute of Information Technol...  Bengaluru  Karnataka
# 77  M. S. Ramaiah Institute of TechnologyMore Deta...  Bengaluru  Karnataka
# 95        R.V. College of EngineeringMore Details | |  Bengaluru  Karnataka
#
#     Score  Rank
# 73  46.58    74
# 77  45.99    78
# 95  42.22    96

# %% [markdown]
# ### NIRF HYDERABAD RANKINGS

# %%
df1[df1['City']=="Hyderabad"]
# Out:
#                                                  Name       City      State  \
# 7   Indian Institute of Technology HyderabadMore D...  Hyderabad  Telangana
# 54  International Institute of Information Technol...  Hyderabad  Telangana
# 70            University of HyderabadMore Details | |  Hyderabad  Telangana
# 82  Jawaharlal Nehru Technological UniversityMore ...  Hyderabad  Telangana
#
#     Score  Rank
# 7   70.28     8
# 54  50.33    55
# 70  47.51    71
# 82  44.75    83
