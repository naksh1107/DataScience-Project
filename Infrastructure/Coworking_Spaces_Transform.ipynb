# %%
import googlemaps
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests

# %% [markdown]
# # Coworking Spaces Data

# %% [markdown]
# ## Reading from excel files

# %%
df1= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='91Springboard Bangalore')
df2= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='Wework Bangalore')
df7= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='Awfis Bangalore')
df9= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='Regus Bangalore')
df11= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='innov8 Bangalore')
df3= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='91Springboard Hyderabad')
df4= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='Wework Hyderabad')
df8= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='Awfis Hyderabad')
df10= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='Regus Hyderabad')
df12= pd.read_excel('Cowork_Spaces.xlsx', sheet_name='innov8 Hyderabad')

# %% [markdown]
# ## A) 91SpringBoard solutions in Bangalore

# %%
df1.head(100)
# Out:
#                          Location  \
# 0   Outer Ring Road, Mahadevapura
# 1   Outer Ring Road, Mahadevapura
# 2   Outer Ring Road, Mahadevapura
# 3   Outer Ring Road, Mahadevapura
# 4    ITPL Main Road, Mahadevapura
# 5    ITPL Main Road, Mahadevapura
# 6    ITPL Main Road, Mahadevapura
# 7    ITPL Main Road, Mahadevapura
# 8          8th Block, Koramangala
# 9          8th Block, Koramangala
# 10         8th Block, Koramangala
# 11         8th Block, Koramangala
# 12                        MG Road
# 13                        MG Road
# 14                        MG Road
# 15                        MG Road
# 16                    Indiranagar
# 17                    Indiranagar
# 18                    Indiranagar
# 19                    Indiranagar
# 20                      J.P Nagar
# 21                      J.P Nagar
# 22                      J.P Nagar
# 23                      J.P Nagar
#
#                                          Connectivity        Solutions   Price
# ...

# %% [markdown]
# ## B) WeWork solutions in Bangalore

# %%
df2.head(100)
# Out:
#                            Name  \
# 0     WeWork Prestige Tech Park
# 1        WeWork Roshni Tech Hub
# 2            WeWork Embassy One
# 3    WeWork Vaishnavi Signature
# 4   WeWork Salarpuria Magnifica
# 5   WeWork Salarpuria Symbiosis
# 6          WeWork Prestige Cube
# 7        WeWork Manyata Redwood
# 8                WeWork Manyata
# 9    WeWork Embassy TechVillage
# 10          WeWork RMZ Latitude
# 11           WeWork Princeville
# 12              WeWork Sunriver
# 13          WeWork Cherry Hills
# 14      WeWork Prestige Atlanta
# 15            WeWork IWF Campus
# 16          WeWork The Pavilion
# 17                WeWork Galaxy
# 18      WeWork Prestige Central
# 19         WeWork Embassy Quest
# 20        WeWork Cinnabar Hills
#
#                                              Location  \
# 0                   Jupiter block, Prestige Tech Park
# 1   BBMP Khatha No. 1395, Sy.No. 26 (P), Marathaha...
# 2                           8, Bellary Rd, Ganganagar
# ...

# %% [markdown]
# ## C) 91SpringBoard Solutions in Hyderabad

# %%
df3.head(100)
# Out:
#            Location                                       Connectivity  \
# 0   HITEC- Madhapur  Just 1KM away from the Hitec Metro Station, Op...
# 1   HITEC- Madhapur  Just 1KM away from the Hitec Metro Station, Op...
# 2   HITEC- Madhapur  Just 1KM away from the Hitec Metro Station, Op...
# 3   HITEC- Madhapur  Just 1KM away from the Hitec Metro Station, Op...
# 4  HITEC - Kondapur  Located on Gachibowli-Miyapur Road, Opposite t...
# 5  HITEC - Kondapur  Located on Gachibowli-Miyapur Road, Opposite t...
# 6  HITEC - Kondapur  Located on Gachibowli-Miyapur Road, Opposite t...
# 7  HITEC - Kondapur  Located on Gachibowli-Miyapur Road, Opposite t...
#
#          Solutions   Price
# 0   Private Cabin:  10,900
# 1  Open Dedicated:   9,150
# 2      Open Flexi:   7,500
# 3       Part Time:   6,300
# 4   Private Cabin:  10,400
# 5  Open Dedicated:   8,650
# 6      Open Flexi:   7,000
# 7       Part Time:   5,900

# %% [markdown]
# ## D) WeWork Solutions in Hyderabad

# %%
df4.head(100)
# Out:
#                        Name                                       Location  \
# 0   WeWork Raheja Mindspace        Building no.9, Raheja Mindspace IT Park
# 1     WeWork Krishe Emerald           Kondapur Main Road, Laxmi Cyber City
# 2          WeWork RMZ Spire  RMZ Spire, C9MM+5QX, Silpa Gram Craft Village
# 3  WeWork Rajapushpa Summit                Nanakramguda Financial District
#
#                                            Amenities Price/Desk/Month
# 0  Conferencing facilities,Wellness room,F & B ma...           19,000
# 1     Quiet space,Conferencing facilities,Chai Point           17,000
# 2       Conferencing facilities,F & B market,Parking           21,500
# 3             Conferencing facilities,Chai Point,Gym           19,000

# %% [markdown]
# ## E) Awfis Solutions in Hyderabad

# %%
df8.head(100)
# Out:
#                                    Name  \
# 0             Coworking-Jyothi Granules
# 1             Coworking-Jyothi Granules
# 2            Coworking-Prestige Skytech
# 3            Coworking-Prestige Skytech
# 4             Coworking-Aurobindo Orbit
# 5             Coworking-Aurobindo Orbit
# 6            Coworking-Laxmi Cyber City
# 7            Coworking-Laxmi Cyber City
# 8        Coworking-DSL Abacus IT Park 3
# 9             Coworking-Ohris Tech Park
# 10            Coworking-Ohris Tech Park
# 11           Premium Coworking-NSL ICON
# 12              Coworking-MyScape Weave
# 13              Coworking-MyScape Weave
# 14   Coworking-Oyster Complex Begumpet2
# 15       Coworking-DSL Abacus IT Park 2
# 16         Coworking-DSL Abacus IT Park
# 17   Premium Coworking-Prestige Phoenix
# 18  Premium Coworking-Rajapushpa Summit
# 19  Premium Coworking-Rajapushpa Summit
# 20        Coworking-Vasavi MPM Ameerpet
# 21        Coworking-Vasavi MPM Ameerpet
# ...

# %% [markdown]
# ## F) Awfis Solutions in Bangalore

# %%
df7.head(100)
# Out:
#                                           Name  \
# 0                    Coworking-Mantri Commerce
# 1                    Coworking-Mantri Commerce
# 2               Coworking-Brigade Metropolis 2
# 3               Coworking-Brigade Metropolis 2
# 4                        Coworking-Vista Pixel
# 5                        Coworking-Vista Pixel
# 6                Coworking-The Estate Building
# 7          Coworking-Prestige Technology Park2
# 8          Coworking-Prestige Technology Park2
# 9            Coworking-Prestige Shantiniketan3
# 10           Coworking-Prestige Shantiniketan3
# 11                Coworking-Brigade Metropolis
# 12                    Coworking-Vajram Esteva3
# 13                    Coworking-Vajram Esteva3
# 14                  Coworking-Residency Square
# 15                  Coworking-Residency Square
# 16                   Coworking-Prestige Dotcom
# 17                   Coworking-Prestige Dotcom
# 18                    Coworking-Vajram Esteva2
# ...

# %% [markdown]
# ## G) Regus Solutuons in Bangalore

# %%
df9.head(100)
# Out:
#                                  Name  \
# 0               Fairway Business Park
# 1                       Raheja Towers
# 2                 The Estate Building
# 3                    Global Tech Park
# 4                             BCM One
# 5                     Concorde Towers
# 6                        Senam Optima
# 7         Sulochana Dureswamy Complex
# 8                         BL Commerce
# 9                   Praksanda Tower 1
# 10  Supreme Overseas Exports Building
# 11                   Tejas Arcade 527
# 12       World Trade Centre Bangalore
# 13   Manyata Embassy Business Park E1
# 14                 Brigade IRV Centre
# 15                         BCM Vertex
# 16                   Crescent Tower 4
# 17                      Tech 37 Ecity
# 18           Brigade Signature Towers
#
#                                              Location     Solutions   Price
# 0   Fairway Business Park Behind Dell, Next to Emb...  Office Space  28,090
# ...

# %% [markdown]
# ## G) Regus Solutuons in Hyderabad

# %%
df10.head(100)
# Out:
#                     Name                                           Location  \
# 0             SL Jubilee  Road No.36 Plot No.1202 & 1215A, 3rd Floor, SL...
# 1   Apurupa Turbo Towers  H No 8-2-293/82/A/787/1/4F/1, Rd Number 36, Ju...
# 2           iLabs Centre  Level 2, Oval Building Plot no.18 iLabs, Hyder...
# 3    Hyderabad Telangana  Krithika Layout Plot No 3, Hyderabad, Telangan...
# 4         Mid Town Plaza  Level 1, Midtown Building Road no. 1 Banjara H...
# 5             Sixty Walk  New Administrative Capital, Financial District...
# 6            Acendia Arc  SY NO.12, White Field, Lingampalli, Serilingam...
# 7           SLN Terminus  Survey NO126, SS Tech Park 8th Floor, Gachibow...
# 8       Gumidelli Towers  1-10-39 to 44 , Level 4, Gumidelli Towers Old ...
# 9        Kothari Centrum  Level 4, KOTHARI CENTRUM Plot Nos # 12, 13, 14...
# 10         MyScape Weave  Survey No. 322(P), Puppalaguda Village Behind ...
# ...

# %% [markdown]
# ## H) Innov8 Solutuons in Bangalore

# %%
df11.head(100)
# Out:
#                                       Name  \
# 0   innov8 mantri 5th floor, bellandur orr
# 1   innov8 mantri 5th floor, bellandur orr
# 2   innov8 mantri 5th floor, bellandur orr
# 3   innov8 mantri 5th floor, bellandur orr
# 4   innov8 mantri 5th floor, bellandur orr
# 5   innov8 mantri 5th floor, bellandur orr
# 6      workflo umiya emporium, koramangala
# 7      workflo umiya emporium, koramangala
# 8      workflo umiya emporium, koramangala
# 9      workflo umiya emporium, koramangala
# 10     workflo umiya emporium, koramangala
# 11   workflo ranka junction, kr puram, orr
# 12   workflo ranka junction, kr puram, orr
# 13   workflo ranka junction, kr puram, orr
# 14   workflo ranka junction, kr puram, orr
# 15   workflo ranka junction, kr puram, orr
#
#                                              Location           Solutions  \
# 0   Devara Vishanvli Road, Devarabisanahalli, Bell...          Fixed Desk
# ...

# %% [markdown]
# ## I) Innov8 Solutuons in Hyderabad

# %%
df12.head(100)
# Out:
#                                        Name  \
# 0  workflo hitex bizness square, hitec city
# 1  workflo hitex bizness square, hitec city
# 2  workflo hitex bizness square, hitec city
# 3  workflo hitex bizness square, hitec city
# 4  workflo hitex bizness square, hitec city
# 5  workflo hitex bizness square, hitec city
#
#                                             Location           Solutions  \
# 0  4th & 5th Floor, Bizness Square, Opposite Hite...          Fixed Desk
# 1  4th & 5th Floor, Bizness Square, Opposite Hite...        Meeting Room
# 2  4th & 5th Floor, Bizness Square, Opposite Hite...            Hot Desk
# 3  4th & 5th Floor, Bizness Square, Opposite Hite...       Private Cabin
# 4  4th & 5th Floor, Bizness Square, Opposite Hite...  Muti-utility Space
# 5  4th & 5th Floor, Bizness Square, Opposite Hite...          Flexi Pass
#
#      Price     Per
# 0   6,999    month
# 1     400       hr
# 2      NaN     NaN
# 3   7,999    month
# 4   2,000       hr
# ...

# %% [markdown]
# # Cleaning and Preparing the Data for Analysis

# %% [markdown]
# ## Bangalore Database

# %%
df2["Amenities"]='Private office'
df2.rename(columns={'Amenities': 'Solutions'}, inplace=True)

# %%
df1.insert(0, 'Website', '91SpringBoard')
df2.insert(0, 'Website', 'Wework')
df7.insert(0, 'Website', 'Awfis')
df9.insert(0, 'Website', 'Regus')
df11.insert(0, 'Website', 'Innov8')

# %%
df7 = df7.drop(columns=['Seats'])
values_to_drop=['Meeting Room','Hot Desk','Muti-utility Space','Flexi Pass']
df11 = df11.query('Solutions not in @values_to_drop')
df11 = df11.drop(columns=['Per'])

# %%
df1.rename(columns={'Location': 'Name','Connectivity':'Location'}, inplace=True)
df2.rename(columns={'Price/Desk/Month': 'Price'}, inplace=True)

# %%
df_blr = pd.concat([df1, df2, df7, df9, df11], axis=0, ignore_index=True)

# %%
pd.options.display.max_rows = 999

# %%
df_blr=df_blr.dropna(subset=['Price'])

# %%
values_to_drop=['Open Flexi:','Part Time:','NA']
df_blr = df_blr.query('Solutions not in @values_to_drop')
df_blr = df_blr.query('Price not in @values_to_drop')

# %%
df_blr.reset_index(drop=True, inplace=True)

# %%
import googlemaps

def find_nearest_metro(location,Distance_from_station):
    distanceList=[]
    distanceDict={}
    gmaps = googlemaps.Client(key='AIzaSyD87vdo5q0CfIRYFr7ld1yqiFkF5KVA3l4')
    place_coordinates=gmaps.geocode(location)
    
    lat_origin=place_coordinates[0]['geometry']['location']['lat']
    long_origin=place_coordinates[0]['geometry']['location']['lng']
    origin_location = str(lat_origin)+','+str(long_origin)  # Latitude, Longitude
    radius = 10000 # Search radius in meters
    type = "subway_station"
    places = gmaps.places_nearby(location=origin_location, radius=radius, type=type)
    for place in places["results"]:
        lat_destination=place['geometry']['location']['lat']
        long_destination=place['geometry']['location']['lng']
        destination_location=str(lat_destination)+','+str(long_destination)
        distance=gmaps.distance_matrix(origins=origin_location,destinations=destination_location)
        distance_main=distance["rows"][0]["elements"][0]["distance"]["value"]
        distanceList.append(distance_main)
        name=place['name']
        distanceDict[name]=distance_main
        
    distanceList.sort()
    value = [i for i in distanceDict if distanceDict[i]==distanceList[0]]
    Distance_from_station.append(distanceDict[value[0]])
    return value[0]

# %%
column_names=df_blr['Location'].tolist()
Nearby_metro=[]
Distance_from_station=[]
for i in range(len(column_names)):
    try:
        metro=find_nearest_metro(column_names[i],Distance_from_station)
        Nearby_metro.append(metro)
    except:
        Nearby_metro.append("NA")
        Distance_from_station.append("NA")

# %%
df_blr['Nearest Metro Station']=Nearby_metro
df_blr.insert(6, 'Distance From Metro',Distance_from_station)

# %%
def get_ratings(location_text):
    gmaps = googlemaps.Client(key='AIzaSyD87vdo5q0CfIRYFr7ld1yqiFkF5KVA3l4')
    Place_id = gmaps.find_place(input=location_text,input_type='textquery')
 
    place_details=gmaps.place(place_id=Place_id['candidates'][0]['place_id'])
    return place_details['result']['rating']

# %%
def price_to_int(df):
    for i in range(len(df)):
        try:
            new=df.loc[i,'Price'].replace(',','')
            df.loc[i,'Price']=int(new)
        except:
            pass

# %%
price_to_int(df_blr)

# %%
ratings=[]
for i in range(len(df_blr)):
    try:
        if df_blr.loc[i,'Website']=='91SpringBoard':
            location_text='91SpringBoard'+','+df_blr.loc[i,'Name']
            rating=get_ratings(location_text)
            ratings.append(rating)
        elif df_blr.loc[i,'Website']=='Awfis':
            location_text='Awfis'+','+df_blr.loc[i,'Location']
            rating=get_ratings(location_text)
            ratings.append(rating)
        else:
            location_text=df_blr.loc[i,'Website']+','+df_blr.loc[i,'Name']
            rating=get_ratings(location_text)
            ratings.append(rating)
    except:
        ratings.append("NA")

# %%
df_blr['Ratings']=ratings
for i in range(len(df_hyd)):
    if df_blr.loc[i,'Ratings']==5:
        df_blr.loc[i,'Ratings']='NA'

# %%
df_blr.loc[6,'Nearest Metro Station']='Mahatma Gandhi Road'
df_blr.loc[7,'Nearest Metro Station']='Mahatma Gandhi Road'
df_blr.loc[6,'Distance From Metro']=500
df_blr.loc[7,'Distance From Metro']=500
df_blr.loc[8,'Distance From Metro']=400
df_blr.loc[9,'Distance From Metro']=400
df_blr.loc[42,'Area Name']='Hoodi'
df_blr.loc[43,'Area Name']='Hoodi'

# %%
df_blr
# Out:
#           Website                                        Name  \
# 0   91SpringBoard               Outer Ring Road, Mahadevapura
# 1   91SpringBoard               Outer Ring Road, Mahadevapura
# 2   91SpringBoard                ITPL Main Road, Mahadevapura
# 3   91SpringBoard                ITPL Main Road, Mahadevapura
# 4   91SpringBoard                      8th Block, Koramangala
# 5   91SpringBoard                      8th Block, Koramangala
# 6   91SpringBoard                                     MG Road
# 7   91SpringBoard                                     MG Road
# 8   91SpringBoard                                 Indiranagar
# 9   91SpringBoard                                 Indiranagar
# 10  91SpringBoard                                   J.P Nagar
# 11  91SpringBoard                                   J.P Nagar
# 12         Wework                   WeWork Prestige Tech Park
# 13         Wework                      WeWork Roshni Tech Hub
# ...

# %% [markdown]
# ## Hyderabad Database

# %%
df4["Amenities"]='Private office'
df4.rename(columns={'Amenities': 'Solutions'}, inplace=True)

# %%
df3.insert(0, 'Website', '91SpringBoard')
df4.insert(0, 'Website', 'Wework')
df8.insert(0, 'Website', 'Awfis')
df10.insert(0, 'Website', 'Regus')
df12.insert(0, 'Website', 'Innov8')

# %%
df8 = df8.drop(columns=['Seats'])
values_to_drop=['Meeting Room','Hot Desk','Muti-utility Space','Flexi Pass']
df12 = df12.query('Solutions not in @values_to_drop')
df12 = df12.drop(columns=['Per'])

# %%
df3.rename(columns={'Location': 'Name','Connectivity':'Location'}, inplace=True)
df4.rename(columns={'Price/Desk/Month': 'Price'}, inplace=True)

# %%
df_hyd = pd.concat([df3, df4, df8, df10, df12], axis=0, ignore_index=True)

# %%
df_hyd=df_hyd.dropna(subset=['Price'])

# %%
values_to_drop=['Open Flexi:','Part Time:','NA']
df_hyd = df_hyd.query('Solutions not in @values_to_drop')
df_hyd = df_hyd.query('Price not in @values_to_drop')

# %%
df_hyd.reset_index(drop=True, inplace=True)

# %%
column_names=df_hyd['Location'].tolist()
Nearby_metro=[]
Distance_from_station=[]
for i in range(len(column_names)):
    try:
        metro=find_nearest_metro(column_names[i],Distance_from_station)
        Nearby_metro.append(metro)
    except:
        Nearby_metro.append("NA")
        Distance_from_station.append("NA")

# %%
df_hyd['Nearest Metro Station']=Nearby_metro
df_hyd.insert(6, 'Distance From Metro',Distance_from_station)

# %%
ratings=[]
for i in range(len(df_hyd)):
    try:
        if df_hyd.loc[i,'Website']=='91SpringBoard':
            location_text='91SpringBoard'+','+df_hyd.loc[i,'Name']
            rating=get_ratings(location_text)
            ratings.append(rating)
        elif df_hyd.loc[i,'Website']=='Awfis':
            location_text='Awfis'+','+df_hyd.loc[i,'Location']
            rating=get_ratings(location_text)
            ratings.append(rating)
        else:
            location_text=df_hyd.loc[i,'Website']+','+df_hyd.loc[i,'Name']
            rating=get_ratings(location_text)
            ratings.append(rating)
    except:
        ratings.append("NA")

# %%
df_hyd['Ratings']=ratings
for i in range(len(df_hyd)):
    if df_hyd.loc[i,'Ratings']==5:
        df_hyd.loc[i,'Ratings']='NA'

# %%
price_to_int(df_hyd)

# %%
df_hyd.reset_index(drop=True, inplace=True)
df_hyd=df_hyd.drop(56)
df_hyd.reset_index(drop=True, inplace=True)

# %%
df_hyd
# Out:
#           Website                                      Name  \
# 0   91SpringBoard                           HITEC- Madhapur
# 1   91SpringBoard                           HITEC- Madhapur
# 2   91SpringBoard                          HITEC - Kondapur
# 3   91SpringBoard                          HITEC - Kondapur
# 4          Wework                   WeWork Raheja Mindspace
# 5          Wework                     WeWork Krishe Emerald
# 6          Wework                          WeWork RMZ Spire
# 7          Wework                  WeWork Rajapushpa Summit
# 8           Awfis                 Coworking-Jyothi Granules
# 9           Awfis                 Coworking-Jyothi Granules
# 10          Awfis                Coworking-Prestige Skytech
# 11          Awfis                Coworking-Prestige Skytech
# 12          Awfis                 Coworking-Aurobindo Orbit
# 13          Awfis                 Coworking-Aurobindo Orbit
# 14          Awfis                Coworking-Laxmi Cyber City
# ...

# %% [markdown]
# # Feature Engineering

# %%
def get_area_name(api_key, place_name):
    url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
    params = {
        'input': place_name,
        'inputtype': 'textquery',
        'fields': 'formatted_address',
        'key': api_key
    }
    response = requests.get(url,params=params)

    if response.status_code == 200:
        data = response.json()
        
        if 'candidates' in data and len(data['candidates']) > 0:
            result = data['candidates'][0]
            if 'formatted_address' in result:
                return result['formatted_address']
            else:
                return "Area name not found in the response."
        else:
            return "No result found in the response."
    else:
        return f"Error: HTTP {response.status_code}"

# %%
Area_Name1=[]
Area_Name=[]
api_key = 'AIzaSyD87vdo5q0CfIRYFr7ld1yqiFkF5KVA3l4'
for i in range(len(df_blr)):
    if df_blr.loc[i,"Website"]=="91SpringBoard":
        place_name=df_blr.loc[i,"Name"]
        area_name = get_area_name(api_key, f"{place_name},Bangalore")
        Area_Name1.append(area_name.split(','))
    else:
        place_name=df_blr.loc[i,"Location"]
        area_name = get_area_name(api_key, f"{place_name},Bangalore")
        Area_Name1.append(area_name.split(','))

for j in Area_Name1:
    newList=[area.strip() for area in j]
    if "Bengaluru" in newList:
        prev=''
        
        for i in newList:
            if i=="Bengaluru":
                Area_Name.append(prev)

            prev=i
    elif any(area.strip().startswith("Karnataka") for area in newList):
        prev=''
        for k in newList:
            if k.startswith("Karnataka"):
                Area_Name.append(prev)
            prev=k
    else: 
        Area_Name.append("NA")

# %%
df_blr['Area Name']=Area_Name

# %%
Area_Name1=[]
Area_Name=[]
api_key = 'AIzaSyD87vdo5q0CfIRYFr7ld1yqiFkF5KVA3l4'
for i in range(len(df_hyd)):
    if df_hyd.loc[i,"Website"]=="91SpringBoard":
        place_name=df_hyd.loc[i,"Name"]
        area_name = get_area_name(api_key, f"{place_name},Hyderabad")
        Area_Name1.append(area_name.split(','))
    else:
        place_name=df_hyd.loc[i,"Location"]
        area_name = get_area_name(api_key, f"{place_name},Hyderabad")
        Area_Name1.append(area_name.split(','))

for j in Area_Name1:
    newList=[area.strip() for area in j]
    if "Hyderabad" in newList:
        prev=''
        
        for i in newList:
            if i=="Hyderabad":
                Area_Name.append(prev)

            prev=i
    elif any(area.strip().startswith("Telangana") for area in newList):
        prev=''
        for k in newList:
            if k.startswith("Telangana"):
                Area_Name.append(prev)
            prev=k
    elif any(area.strip().startswith("India") for area in newList):
        prev=''
        for k in newList:
            if k.startswith("India"):
                Area_Name.append(prev)
            prev=k
    else: 
        Area_Name.append("NA")

# %%
df_hyd['Area Name']=Area_Name

# %%
def InTechPark(TechParks,df):
    InTechPark=[]
    combined_strings = df.apply(lambda row: f"{row['Name']},{row['Location']}", axis=1)
    for i in combined_strings:
        Temp=''
        for j in TechParks:
            if j in i:
                InTechPark.append("Yes")
                Temp='Yes'
                break
        if Temp=='':
            InTechPark.append("No")
    df['InTechPark']=InTechPark

# %%
TechParks=['ITPL','Embassy Manyata Business Park','Bagmane Tech Park','Embassy TechVillage','Electronic City Tech Park','Kalyani Tech Park','Global Village Tech Park','RMZ Latitude','Embassy Golf Links','RMZ Ecoworld','Prestige Tech','Roshni Tech Hub','Vaishnavi Signature','Kirloskar Business Park','Fairway Business Park','Global Tech Park','Concorde Towers','Tech 37 Ecity','Brigade Signature Towers']
InTechPark(TechParks,df_blr)
df_blr2=df_blr.copy()

# %%
TechParks=['Hitec','HITEC','HiTECH','Prestige Skytech','DSL Abacus IT Park','Laxmi Cyber City','Mindspace IT Park','iLabs Centre','SLN Terminus','Manjeera Trinity Corporate']
InTechPark(TechParks,df_hyd)
df_hyd2=df_hyd.copy()

# %%
def bangalore_transform(wrtier,df):
     df.to_excel(writer,sheet_name='Bangalore_transformed')
def hyderabad_transform(writer,df):
     df.to_excel(writer,sheet_name='Hyderabad_transformed')
    

with pd.ExcelWriter('Cowork_Space_transform.xlsx') as writer:
     bangalore_transform(writer,df_blr)
     hyderabad_transform(writer,df_hyd)
